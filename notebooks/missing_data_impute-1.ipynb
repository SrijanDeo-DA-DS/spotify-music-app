# %%
import pandas as pd
import numpy as np
import os,sys

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
home = os.getcwd()
df = pd.read_csv('C:/Users/Srijan-DS/Documents/Projects/spotify-music-app/artifact/data_ingestion/2024-06-06 16-18-23/ingested_dir/train.csv')

# %%
df.sample(5)
# Out:
#       Unnamed: 0                             Track URI  \
# 2442        6103  spotify:track:1IDQQo4AbWYgwbxESIn5xZ
# 7980        4555  spotify:track:5gTt2nqWQEVnkvwuUgcqsw
# 5160        1602  spotify:track:2d4e45fmUnguxh6yqC7gNT
# 3116         191  spotify:track:1DSJNBNhGZCigg9ll5VeZv
# 3119        1942  spotify:track:1RgQ8sBbzoRXBV78Tn6hQA
#
#                        Track Name  \
# 2442   Jump (feat. Nelly Furtado)
# 7980                   Moon River
# 5160  Dirty Deeds Done Dirt Cheap
# 3116         (You Drive Me) Crazy
# 3119  Sitting on Top of the World
#
#                                           Artist URI(s)  \
# 2442  spotify:artist:0jnsk9HBra6NMjO2oANoPY, spotify...
# 7980              spotify:artist:2EExdpjU4SK3xnJHO5paJf
# 5160              spotify:artist:711MCceyCBcFnzjGY4Q7Un
# 3116              spotify:artist:26dSoYclwsYLMAKD3tpOr4
# 3119              spotify:artist:2g6fa86fL6oLcoDqanBbuR
#
#                Artist Name(s)                             Album URI  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            7999 non-null   int64
#  1   Track URI             7999 non-null   object
#  2   Track Name            7999 non-null   object
#  3   Artist URI(s)         7997 non-null   object
#  4   Artist Name(s)        7999 non-null   object
#  5   Album URI             7997 non-null   object
#  6   Album Name            7999 non-null   object
#  7   Album Artist URI(s)   7997 non-null   object
#  8   Album Artist Name(s)  7997 non-null   object
#  9   Album Release Date    7997 non-null   object
#  10  Album Image URL       7997 non-null   object
#  11  Disc Number           7999 non-null   int64
#  12  Track Number          7999 non-null   int64
#  13  Track Duration (ms)   7999 non-null   int64
#  14  Track Preview URL     5709 non-null   object
# ...

# %% [markdown]
# * Important step is to remove redundant columns that wouldn't be required for prediction
# * We will try to predict popularity score of a song

# %%
redundant_cols = ['Unnamed: 0','Track URI','Artist URI(s)','Album URI','Album Artist URI(s)','Album Image URL','Track Preview URL',
                  'ISRC','Added By','Album Genres','Track Number']

df = df.drop(redundant_cols,axis=1)

# %% [markdown]
# ##### We will be using Tree based model for Prediction.
# ##### Hence, we will not perform outlier analysis and feature scaling

# %%
## Missing value imputation

round(df.isnull().sum() / df.shape[0] * 100, 2)
# Out:
# Track Name              0.00
# Artist Name(s)          0.00
# Album Name              0.00
# Album Artist Name(s)    0.03
# Album Release Date      0.03
# Disc Number             0.00
# Track Duration (ms)     0.00
# Explicit                0.00
# Popularity              0.00
# Added At                0.00
# Artist Genres           5.45
# Danceability            0.03
# Energy                  0.03
# Key                     0.03
# Loudness                0.03
# Mode                    0.03
# Speechiness             0.03
# Acousticness            0.03
# Instrumentalness        0.03
# Liveness                0.03
# Valence                 0.03
# Tempo                   0.03
# Time Signature          0.03
# Label                   0.03
# Copyrights              0.23
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Track Name                0
# Artist Name(s)            0
# Album Name                0
# Album Artist Name(s)      2
# Album Release Date        2
# Disc Number               0
# Track Duration (ms)       0
# Explicit                  0
# Popularity                0
# Added At                  0
# Artist Genres           436
# Danceability              2
# Energy                    2
# Key                       2
# Loudness                  2
# Mode                      2
# Speechiness               2
# Acousticness              2
# Instrumentalness          2
# Liveness                  2
# Valence                   2
# Tempo                     2
# Time Signature            2
# Label                     2
# Copyrights               18
# dtype: int64
